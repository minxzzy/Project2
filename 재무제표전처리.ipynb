# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import winsorize

# %%
full = pd.read_csv('csv/feature/후보피처(6990).csv', index_col=0)
full
# Out:
#        Symbol     Name   회계년  결산월      주기      총자산(천원)  총자산(평균)(천원)  \
# 0     A298380  에이비엘바이오  2022   12  Annual  185180596.0  125316676.0
# 1     A028080   휴맥스홀딩스  2019   12  Annual  169615218.0  166898026.0
# 2     A293780    압타바이오  2020   12  Annual   75443708.0   76423984.0
# 3     A028080   휴맥스홀딩스  2018   12  Annual  164180834.0  178404283.0
# 4     A293780    압타바이오  2021   12  Annual   64910601.0   70177155.0
# ...       ...      ...   ...  ...     ...          ...          ...
# 6985  A284620   카이노스메드  2018   12  Annual    8189385.0    7888376.0
# 6986  A284620   카이노스메드  2019   12  Annual    5571348.0    6880366.0
# 6987  A115180     큐리언트  2020   12  Annual   60810746.0   40662141.0
# 6988  A284620   카이노스메드  2020   12  Annual   34778564.0   20174956.0
# 6989  A001000     신라섬유  2017   12  Annual   32122070.0   32321473.0
#
#         유동자산(천원)    당좌자산(천원)  현금및현금성자산(천원)  ...    기말현금(천원)    현금흐름(천원)  \
# 0     80534637.0  80534637.0    25135625.0  ...  25135625.0   5533457.0
# ...

# %% [markdown]
# ### 포함 컬럼 찾기

# %%
full.columns[full.columns.str.contains('금융원가')]
# Out:
# Index(['금융원가(비영업)(천원)'], dtype='object')

# %% [markdown]
# ## 증가율

# %%
up = pd.read_csv('csv/재무/증가율.csv', index_col=0)
up
# Out:
#        Symbol     Name   회계년  판매비와관리비(천원)    영업이익(천원)  *조정영업이익(천원)  \
# 0     A298380  에이비엘바이오  2022   66392800.0    907999.0     907999.0
# 1     A028080   휴맥스홀딩스  2019    8220320.0   1033238.0    1033238.0
# 2     A293780    압타바이오  2020    6405832.0  -6064788.0   -6064788.0
# 3     A028080   휴맥스홀딩스  2018   18225481.0 -15081877.0  -15081877.0
# 4     A293780    압타바이오  2021   11590662.0 -11366985.0  -11366985.0
# ...       ...      ...   ...          ...         ...          ...
# 6985  A284620   카이노스메드  2018    7634006.0  -7634006.0   -7634006.0
# 6986  A284620   카이노스메드  2019    8087227.0  -8087227.0   -8087227.0
# 6987  A115180     큐리언트  2020   21024930.0 -21024930.0  -21024930.0
# 6988  A284620   카이노스메드  2020    9385681.0  -9385681.0   -9385681.0
# 6989  A001000     신라섬유  2017     674135.0    537530.0     537530.0
#
#       세전계속사업이익(천원)  계속사업이익(천원)  중단사업이익(천원)   당기순이익(천원)  ...  \
# 0        3208631.0   3208631.0         0.0   3208631.0  ...
# ...

# %%
up.columns[up.columns.str.contains('증가율')]
# Out:
# Index(['판매비와관리비(천원)증가율(전년동기)(%)', '영업이익(천원)증가율(전년동기)(%)',
#        '*조정영업이익(천원)증가율(전년동기)(%)', '세전계속사업이익(천원)증가율(전년동기)(%)',
#        '계속사업이익(천원)증가율(전년동기)(%)', '중단사업이익(천원)증가율(전년동기)(%)',
#        '당기순이익(천원)증가율(전년동기)(%)', '총자본(천원)증가율(전년동기)(%)',
# 6987  A115180     큐리언트  2020        0.0         0.0 -21024930.0 -19957348.0
# 6988  A284620   카이노스메드  2020   763411.0         0.0  -9385681.0 -11027973.0
# 6989  A001000     신라섬유  2017   575227.0   3996989.0    537530.0    580718.0
#
# ...

# %%
borrow.isna().sum()
# Out:
# Symbol               0
# Name                 0
# 회계년                  0
# 이자비용(천원)             0
# 영업수익(천원)             0
# 영업이익(천원)             0
# 현금흐름(천원)             0
# *총차입부채(천원)           0
# *총차입부채(천원)_전년도       0
# 총차입부채(천원)_평균         0
# 차입부채조달금리(평균)(%)    150
# 차입부채조달금리(기말)(%)    168
# 차입부채/영업수익(%)         4
# 차입부채/영업이익(배)         0
# 차입부채/EBITDA(배)       0
# 현금흐름/총차입부채(%)        0
# dtype: int64

# %%
np.isinf(borrow)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 np.isinf(borrow)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:2168, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2164 @final
#    2165 def __array_ufunc__(
#    2166     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2167 ):
# -> 2168     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:407, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     402 if method == "__call__" and not kwargs:
#     403     # for np.<ufunc>(..) calls
#     404     # kwargs cannot necessarily be handled block-by-block, so only
#     405     # take this path if there are no kwargs
#     406     mgr = inputs[0]._mgr
# ...

# %% [markdown]
# ### 차입부채 2차 전처리

# %%
borrow2 = pd.read_csv('csv/재무/차입부채_2차_전처리.csv', index_col=0)
borrow2
# Out:
#        Symbol     Name   회계년   이자비용(천원)     영업수익(천원)    영업이익(천원)    현금흐름(천원)  \
# 0     A037270  YG PLUS  2011    18615.0   29661659.0   -658068.0   1625546.0
# 1     A024070   WISCOM  2018        0.0  111921029.0   -344658.0   4166300.0
# 2     A024070   WISCOM  2020    53592.0  102450919.0  -1721061.0   2751187.0
# 3     A024070   WISCOM  2021    10468.0  117607135.0    -34184.0   5390528.0
# 4     A100840   SNT에너지  2018        0.0  139516396.0  -1892191.0   3887648.0
# ...       ...      ...   ...        ...          ...         ...         ...
# 6985  A045260   디에이치패션  2011   543180.0    3997421.0  -4227818.0  -5275059.0
# 6986  A010580    에스엠벡셀  2021   350255.0   73077586.0  -8181785.0 -12905736.0
# 6987  A002410     범양건영  2012  6317700.0   70088284.0 -25405559.0 -79186250.0
# 6988  A199800       툴젠  2022    28375.0     743464.0 -19385620.0 -17101952.0
# 6989  A043360     디지아이  2019    17517.0   15369640.0  -3300403.0  -2825092.0
#
# ...

# %%
col = full[['Symbol','Name','회계년','금융원가(비영업)(천원)']]
col
# Out:
#        Symbol     Name   회계년  금융원가(비영업)(천원)
# 0     A298380  에이비엘바이오  2022      6971450.0
# 1     A028080   휴맥스홀딩스  2019       580386.0
# 2     A293780    압타바이오  2020       142590.0
# 3     A028080   휴맥스홀딩스  2018       960802.0
# 4     A293780    압타바이오  2021       989864.0
# ...       ...      ...   ...            ...
# 6985  A284620   카이노스메드  2018       397446.0
# 6986  A284620   카이노스메드  2019         8127.0
# 6987  A115180     큐리언트  2020       198240.0
# 6988  A284620   카이노스메드  2020      1160376.0
# 6989  A001000     신라섬유  2017       575227.0
#
# [6990 rows x 4 columns]

# %%
borrow2 = pd.merge(borrow2,col,on=['Symbol','Name','회계년'], how='left')
borrow2
# Out:
#        Symbol     Name   회계년   이자비용(천원)     영업수익(천원)    영업이익(천원)    현금흐름(천원)  \
# 0     A037270  YG PLUS  2011    18615.0   29661659.0   -658068.0   1625546.0
# 1     A024070   WISCOM  2018        0.0  111921029.0   -344658.0   4166300.0
# 2     A024070   WISCOM  2020    53592.0  102450919.0  -1721061.0   2751187.0
# 3     A024070   WISCOM  2021    10468.0  117607135.0    -34184.0   5390528.0
# 4     A100840   SNT에너지  2018        0.0  139516396.0  -1892191.0   3887648.0
# ...       ...      ...   ...        ...          ...         ...         ...
# 6985  A045260   디에이치패션  2011   543180.0    3997421.0  -4227818.0  -5275059.0
# 6986  A010580    에스엠벡셀  2021   350255.0   73077586.0  -8181785.0 -12905736.0
# 6987  A002410     범양건영  2012  6317700.0   70088284.0 -25405559.0 -79186250.0
# 6988  A199800       툴젠  2022    28375.0     743464.0 -19385620.0 -17101952.0
# 6989  A043360     디지아이  2019    17517.0   15369640.0  -3300403.0  -2825092.0
#
# ...

# %%
borrow2.to_csv('csv/재무/차입부채_2차_전처리.csv', encoding='utf-8-sig')

# %%
df1 = pd.read_csv('csv/재무/차입부채_3차_전처리.csv', index_col=0)
df2 = pd.read_csv('csv/재무/증가율_2차_전처리.csv', index_col=0)
df3 = pd.read_csv('csv/재무/유동비율~광고선전비_작업한것.csv', index_col=0)
df4 = pd.read_csv('csv/재무/매출채권회전율.csv', index_col=0)
df5 = pd.read_csv('csv/재무/차입부채재고자산회전율증가율.csv', index_col=0)

# %%
df5.columns
# Out:
# Index(['Symbol', 'Name', '회계년', 'label_shifted_x', 'label_shifted_y',
#        '총차입부채회전율증가율(%)', '재고자산회전율증가율(%)'],
#       dtype='object')

# %%
df1 = df1[['Symbol', 'Name', '회계년','차입부채조달금리(평균)(%)',
       '차입부채조달금리(기말)(%)', '차입부채/영업수익(%)', '차입부채/영업이익(배)', '차입부채/EBITDA(배)',
       '현금흐름/총차입부채(%)']]

df2 = df2[['Symbol', 'Name', '회계년','판매비와관리비(천원)증가율(전년동기)(%)', '영업이익(천원)증가율(전년동기)(%)',
       '*조정영업이익(천원)증가율(전년동기)(%)', '세전계속사업이익(천원)증가율(전년동기)(%)',
       '계속사업이익(천원)증가율(전년동기)(%)', '중단사업이익(천원)증가율(전년동기)(%)',
       '당기순이익(천원)증가율(전년동기)(%)', '총자본(천원)증가율(전년동기)(%)',
       '*총차입부채(천원)증가율(전년동기)(%)', '총포괄이익(천원)증가율(전년동기)(%)',
       '유동자산(천원)증가율(전년동기)(%)', '비유동자산(천원)증가율(전년동기)(%)', '매출원가(천원)증가율(전년동기)(%)',
       '매출총이익(천원)증가율(전년동기)(%)', 'EBIT(천원)증가율(전년동기)(%)',
       'EBITDA(천원)증가율(전년동기)(%)', '영업활동으로인한현금흐름(천원)증가율(전년동기)(%)',
       '투자활동으로인한현금흐름(천원)증가율(전년동기)(%)', '재무활동으로인한현금흐름(천원)증가율(전년동기)(%)',
       '지배주주순이익(천원)증가율(전년동기)(%)','지배주주지분(천원)증가율(전년동기)(%)', '지배주주총포괄이익(천원)증가율(전년동기)(%)']]

df3 = df3[['Symbol', 'Name', '회계년','유동비율', '비유동비율', '당좌비율', '유동부채비율', '비유동부채비율',
       '순운전자본대 총자본비율', '인건비율']]

df4 = df4[['Symbol', 'Name', '회계년', '매출채권회전율']]

df5 = df5[['Symbol', 'Name', '회계년', '총차입부채회전율증가율(%)', '재고자산회전율증가율(%)']]

# %%
a = pd.merge(df1, df2, on=['Symbol', 'Name', '회계년'], how='left')
b = pd.merge(a, df3, on=['Symbol', 'Name', '회계년'], how='left')
c = pd.merge(b, df4, on=['Symbol', 'Name', '회계년'], how='left')
d = pd.merge(c, df5, on=['Symbol', 'Name', '회계년'], how='left')
d
# Out:
#        Symbol   Name   회계년  차입부채조달금리(평균)(%)  차입부채조달금리(기말)(%)  차입부채/영업수익(%)  \
# 0     A002410   범양건영  2013     10285.306131         0.000000      0.000000
# 1     A030790  비케이탑스  2015      1310.708114         0.000000      0.000000
# 2     A110990   디아이티  2020       676.039601       654.033693      1.247891
# 3     A043360   디지아이  2019       593.796610       918.081761      0.012414
# 4     A110990   디아이티  2021       572.059083       479.549768      0.693071
# ...       ...    ...   ...              ...              ...           ...
# 6984  A003920   남양유업  2013         0.000000         0.000000      0.000000
# 6985  A009140   경인전자  2017         0.000000         0.000000      0.000000
# 6986  A009140   경인전자  2018         0.000000         0.000000      0.000000
# 6987  A058420   제이웨이  2015         0.000000         0.000000      0.000000
# 6988  A139670  키네마스터  2015         0.000000         0.000000      0.000000
#
# ...

# %%
d.columns
# Out:
# Index(['Symbol', 'Name', '회계년', '차입부채조달금리(평균)(%)', '차입부채조달금리(기말)(%)',
#        '차입부채/영업수익(%)', '차입부채/영업이익(배)', '차입부채/EBITDA(배)', '현금흐름/총차입부채(%)',
#        '판매비와관리비(천원)증가율(전년동기)(%)', '영업이익(천원)증가율(전년동기)(%)',
#        '*조정영업이익(천원)증가율(전년동기)(%)', '세전계속사업이익(천원)증가율(전년동기)(%)',
#        '계속사업이익(천원)증가율(전년동기)(%)', '중단사업이익(천원)증가율(전년동기)(%)',
#        '당기순이익(천원)증가율(전년동기)(%)', '총자본(천원)증가율(전년동기)(%)',
#        '*총차입부채(천원)증가율(전년동기)(%)', '총포괄이익(천원)증가율(전년동기)(%)',
#        '유동자산(천원)증가율(전년동기)(%)', '비유동자산(천원)증가율(전년동기)(%)', '매출원가(천원)증가율(전년동기)(%)',
#        '매출총이익(천원)증가율(전년동기)(%)', 'EBIT(천원)증가율(전년동기)(%)',
#        'EBITDA(천원)증가율(전년동기)(%)', '영업활동으로인한현금흐름(천원)증가율(전년동기)(%)',
       '지배주주총포괄이익(천원)증가율(전년동기)(%)', '유동비율', '비유동비율', '당좌비율', '유동부채비율',
       '비유동부채비율', '순운전자본대 총자본비율', '인건비율', '매출채권회전율',
       '총차입부채회전율증가율(%)', '재고자산회전율증가율(%)']]

# %%
np.isinf(e).sum()
# Out:
# 차입부채조달금리(평균)(%)                 0
# 차입부채조달금리(기말)(%)                 0
# 차입부채/영업수익(%)                    0
# 차입부채/영업이익(배)                    0
# 차입부채/EBITDA(배)                  0
# 현금흐름/총차입부채(%)                   0
# 판매비와관리비(천원)증가율(전년동기)(%)         0
# 영업이익(천원)증가율(전년동기)(%)            0
# *조정영업이익(천원)증가율(전년동기)(%)         0
# 세전계속사업이익(천원)증가율(전년동기)(%)        0
# 계속사업이익(천원)증가율(전년동기)(%)          0
# 중단사업이익(천원)증가율(전년동기)(%)          0
# 당기순이익(천원)증가율(전년동기)(%)           0
# 총자본(천원)증가율(전년동기)(%)             0
# *총차입부채(천원)증가율(전년동기)(%)          0
# 총포괄이익(천원)증가율(전년동기)(%)           0
# 유동자산(천원)증가율(전년동기)(%)            0
# 비유동자산(천원)증가율(전년동기)(%)           0
# 매출원가(천원)증가율(전년동기)(%)            0
# 매출총이익(천원)증가율(전년동기)(%)           0
# EBIT(천원)증가율(전년동기)(%)            0
# EBITDA(천원)증가율(전년동기)(%)          0
# 영업활동으로인한현금흐름(천원)증가율(전년동기)(%)    0
# 투자활동으로인한현금흐름(천원)증가율(전년동기)(%)    0
# 재무활동으로인한현금흐름(천원)증가율(전년동기)(%)    0
# 지배주주순이익(천원)증가율(전년동기)(%)         0
# 지배주주지분(천원)증가율(전년동기)(%)          0
# ...

# %%
d.to_csv('csv/feature/재무_후보피처(계산)_6989.csv', encoding='utf-8-sig')

# %%
df0 = pd.read_csv('csv/재무/0529_전처리우선끝1.csv', index_col=0)
df0
# Out:
#        Symbol     Name   회계년  label_shifted  결산월      주기  타인자본비율(%)  \
# 0     A051160    지어소프트  2013              0   12  Annual      51.29
# 1     A005980     성지건설  2017              0   12  Annual      48.24
# 2     A033640      네패스  2020              0   12  Annual      67.49
# 3     A001140       국보  2014              0   12  Annual      75.14
# 4     A067630  HLB생명과학  2022              0   12  Annual      42.67
# ...       ...      ...   ...            ...  ...     ...        ...
# 6984  A005980     성지건설  2011              1   12  Annual      61.86
# 6985  A153710      옵티팜  2019              0   12  Annual      14.65
# 6986  A042940     상지건설  2011              0   12  Annual      61.09
# 6987  A101730   위메이드맥스  2017              0   12  Annual      25.12
# 6988  A140410      메지온  2022              0   12  Annual      51.43
#
#       자기자본비율(%)  차입금의존도(%)  현금및현금성자산구성비율(%)  ...   유보율(%)  유보액/총자산(%)  \
# 0         48.71       4.54             2.08  ...   124.80       23.55
# ...

# %%
df = pd.merge(df0, d, on=['Symbol','Name','회계년'], how='left')
df
# Out:
#        Symbol     Name   회계년  label_shifted  결산월      주기  타인자본비율(%)  \
# 0     A051160    지어소프트  2013              0   12  Annual      51.29
# 1     A005980     성지건설  2017              0   12  Annual      48.24
# 2     A033640      네패스  2020              0   12  Annual      67.49
# 3     A001140       국보  2014              0   12  Annual      75.14
# 4     A067630  HLB생명과학  2022              0   12  Annual      42.67
# ...       ...      ...   ...            ...  ...     ...        ...
# 6984  A005980     성지건설  2011              1   12  Annual      61.86
# 6985  A153710      옵티팜  2019              0   12  Annual      14.65
# 6986  A042940     상지건설  2011              0   12  Annual      61.09
# 6987  A101730   위메이드맥스  2017              0   12  Annual      25.12
# 6988  A140410      메지온  2022              0   12  Annual      51.43
#
#       자기자본비율(%)  차입금의존도(%)  현금및현금성자산구성비율(%)  ...        유동비율       비유동비율  \
# 0         48.71       4.54             2.08  ...   93.246788   45.527924
# ...

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', '회계년', 'label_shifted', '결산월', '주기', '타인자본비율(%)',
#        '자기자본비율(%)', '차입금의존도(%)', '현금및현금성자산구성비율(%)', '유형자산구성비율(%)',
#        '무형자산구성비율(%)', '부채비율(%)', '차입금비율(%)', '현금흐름/총자산(%)', '현금흐름/총자본(%)',
#        '현금흐름/총부채(%)', '현금흐름/영업수익(%)', '자기자본현금흐름률(%)', '매출액증가율(전년동기)(%)',
#        '총자산증가율(전년동기)(%)', '유형자산증가율(전년동기)(%)', '무형자산증가율(전년동기)(%)',
#        '총부채증가율(전년동기)(%)', '자본금증가율(전년동기)(%)', '매출총이익률(%)', '영업이익률(%)',
#        '*조정영업이익률(%)', 'EBITDA마진율(%)', '세전계속사업이익률(%)', '당기순이익률(%)',
#        '지배주주순이익률(%)', '총포괄이익률(%)', '지배주주총포괄이익률(%)', '*매출원가율(%)', '*판관비율(%)',
#        '*영업수익/영업비용(%)', 'ROA(영업이익)(%)', 'ROA(세전계속사업이익)(%)', 'ROA(당기순이익)(%)',
#        'ROA(총포괄이익)(%)', '자본금영업이익률(%)', '자본금세전계속사업이익률(%)', '자본금지배주주순이익률(%)',
#        '총자산회전율(회)', '총부채회전율(회)', '총자본회전율(회)', '자본금회전율(회)', '유보율(%)',
#        '유보액/총자산(%)', 'ROE(영업이익)', 'ROE(세전계속사업이익)', 'ROE(당기순이익)',
#        'ROE(지배주주순이익)', '투하자본회전율', '영업투하자본회전율', '순운전자본회전율', '영업고정자산회전율',
# ...

# %%
dff = df[['타인자본비율(%)',
       '자기자본비율(%)', '차입금의존도(%)', '현금및현금성자산구성비율(%)', '유형자산구성비율(%)',
       '무형자산구성비율(%)', '부채비율(%)', '차입금비율(%)', '현금흐름/총자산(%)', '현금흐름/총자본(%)',
       '현금흐름/총부채(%)', '현금흐름/영업수익(%)', '자기자본현금흐름률(%)', '매출액증가율(전년동기)(%)',
       '총자산증가율(전년동기)(%)', '유형자산증가율(전년동기)(%)', '무형자산증가율(전년동기)(%)',
       '총부채증가율(전년동기)(%)', '자본금증가율(전년동기)(%)', '매출총이익률(%)', '영업이익률(%)',
       '*조정영업이익률(%)', 'EBITDA마진율(%)', '세전계속사업이익률(%)', '당기순이익률(%)',
       '지배주주순이익률(%)', '총포괄이익률(%)', '지배주주총포괄이익률(%)', '*매출원가율(%)', '*판관비율(%)',
       '*영업수익/영업비용(%)', 'ROA(영업이익)(%)', 'ROA(세전계속사업이익)(%)', 'ROA(당기순이익)(%)',
       'ROA(총포괄이익)(%)', '자본금영업이익률(%)', '자본금세전계속사업이익률(%)', '자본금지배주주순이익률(%)',
       '총자산회전율(회)', '총부채회전율(회)', '총자본회전율(회)', '자본금회전율(회)', '유보율(%)',
       '유보액/총자산(%)', 'ROE(영업이익)', 'ROE(세전계속사업이익)', 'ROE(당기순이익)',
       'ROE(지배주주순이익)', '투하자본회전율', '영업투하자본회전율', '순운전자본회전율', '영업고정자산회전율',
       '차입부채조달금리(평균)(%)', '차입부채조달금리(기말)(%)', '차입부채/영업수익(%)', '차입부채/영업이익(배)',
       '차입부채/EBITDA(배)', '현금흐름/총차입부채(%)', '판매비와관리비(천원)증가율(전년동기)(%)',
       '영업이익(천원)증가율(전년동기)(%)', '*조정영업이익(천원)증가율(전년동기)(%)',
       '세전계속사업이익(천원)증가율(전년동기)(%)', '계속사업이익(천원)증가율(전년동기)(%)',
       '중단사업이익(천원)증가율(전년동기)(%)', '당기순이익(천원)증가율(전년동기)(%)',
       '총자본(천원)증가율(전년동기)(%)', '*총차입부채(천원)증가율(전년동기)(%)',
       '총포괄이익(천원)증가율(전년동기)(%)', '유동자산(천원)증가율(전년동기)(%)',
       '비유동자산(천원)증가율(전년동기)(%)', '매출원가(천원)증가율(전년동기)(%)',
       '매출총이익(천원)증가율(전년동기)(%)', 'EBIT(천원)증가율(전년동기)(%)',
       'EBITDA(천원)증가율(전년동기)(%)', '영업활동으로인한현금흐름(천원)증가율(전년동기)(%)',
       '투자활동으로인한현금흐름(천원)증가율(전년동기)(%)', '재무활동으로인한현금흐름(천원)증가율(전년동기)(%)',
       '지배주주순이익(천원)증가율(전년동기)(%)', '지배주주지분(천원)증가율(전년동기)(%)',
       '지배주주총포괄이익(천원)증가율(전년동기)(%)', '유동비율', '비유동비율', '당좌비율', '유동부채비율',
       '비유동부채비율', '순운전자본대 총자본비율', '인건비율', '매출채권회전율', '총차입부채회전율증가율(%)',
       '재고자산회전율증가율(%)']]

# %%
dff[dff.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
dff[np.isinf(dff).any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
df = df.sort_values(by=['Name','회계년'])
df.reset_index(drop=True, inplace=True)
df
# Out:
#        Symbol    Name   회계년  label_shifted  결산월      주기  타인자본비율(%)  자기자본비율(%)  \
# 0     A900010  3노드디지탈  2011              0   12  Annual      68.89      31.11
# 1     A013340     AJS  2013              0   12  Annual      99.85       0.15
# 2     A095570  AJ네트웍스  2018              0   12  Annual      80.90      19.10
# 3     A095570  AJ네트웍스  2019              0   12  Annual      80.74      19.26
# 4     A095570  AJ네트웍스  2020              1   12  Annual      81.87      18.13
# ...       ...     ...   ...            ...  ...     ...        ...        ...
# 6984  A037440      희림  2011              1   12  Annual      52.11      47.89
# 6985  A037440      희림  2014              1   12  Annual      68.89      31.11
# 6986  A238490      힘스  2018              1   12  Annual      19.37      80.63
# 6987  A238490      힘스  2021              0   12  Annual      12.32      87.68
# 6988  A238490      힘스  2022              0   12  Annual      22.12      77.88
#
# ...

# %%
df.to_csv('csv/feature/후보피처(완성본)_6989.csv', encoding='utf-8-sig')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lj/ms0l79910fz22cg2hchczhw40000gn/T/ipykernel_92141/1175589191.py in ?()
#       1 q = pd.DataFrame()
# ----> 2 q[['feature','mean']] = label_0_des.loc['mean']
#       3 q
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4283
#    4284         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4285             self._setitem_frame(key, value)
#    4286         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4287             self._setitem_array(key, value)
#    4288         elif isinstance(value, DataFrame):
#    4289             self._set_item_frame_value(key, value)
#    4290         elif (
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4342                 value = DataFrame(value).values
# ...

# %%
df = pd.read_csv('csv/feature/후보피처(완성본)_6989.csv', index_col=0)
df
# Out:
#        Symbol    Name   회계년  label_shifted  결산월      주기  타인자본비율(%)  자기자본비율(%)  \
# 0     A900010  3노드디지탈  2011              0   12  Annual      68.89      31.11
# 1     A013340     AJS  2013              0   12  Annual      99.85       0.15
# 2     A095570  AJ네트웍스  2018              0   12  Annual      80.90      19.10
# 3     A095570  AJ네트웍스  2019              0   12  Annual      80.74      19.26
# 4     A095570  AJ네트웍스  2020              1   12  Annual      81.87      18.13
# ...       ...     ...   ...            ...  ...     ...        ...        ...
# 6984  A037440      희림  2011              1   12  Annual      52.11      47.89
# 6985  A037440      희림  2014              1   12  Annual      68.89      31.11
# 6986  A238490      힘스  2018              1   12  Annual      19.37      80.63
# 6987  A238490      힘스  2021              0   12  Annual      12.32      87.68
# 6988  A238490      힘스  2022              0   12  Annual      22.12      77.88
#
# ...

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', '회계년', 'label_shifted', '결산월', '주기', '타인자본비율(%)',
#        '자기자본비율(%)', '차입금의존도(%)', '현금및현금성자산구성비율(%)', '유형자산구성비율(%)',
#        '무형자산구성비율(%)', '부채비율(%)', '차입금비율(%)', '현금흐름/총자산(%)', '현금흐름/총자본(%)',
#        '현금흐름/총부채(%)', '현금흐름/영업수익(%)', '자기자본현금흐름률(%)', '매출액증가율(전년동기)(%)',
#        '총자산증가율(전년동기)(%)', '유형자산증가율(전년동기)(%)', '무형자산증가율(전년동기)(%)',
#        '총부채증가율(전년동기)(%)', '자본금증가율(전년동기)(%)', '매출총이익률(%)', '영업이익률(%)',
#        '*조정영업이익률(%)', 'EBITDA마진율(%)', '세전계속사업이익률(%)', '당기순이익률(%)',
#        '지배주주순이익률(%)', '총포괄이익률(%)', '지배주주총포괄이익률(%)', '*매출원가율(%)', '*판관비율(%)',
#        '*영업수익/영업비용(%)', 'ROA(영업이익)(%)', 'ROA(세전계속사업이익)(%)', 'ROA(당기순이익)(%)',
#        'ROA(총포괄이익)(%)', '자본금영업이익률(%)', '자본금세전계속사업이익률(%)', '자본금지배주주순이익률(%)',
#        '총자산회전율(회)', '총부채회전율(회)', '총자본회전율(회)', '자본금회전율(회)', '유보율(%)',
#        '유보액/총자산(%)', 'ROE(영업이익)', 'ROE(세전계속사업이익)', 'ROE(당기순이익)',
#        'ROE(지배주주순이익)', '투하자본회전율', '영업투하자본회전율', '순운전자본회전율', '영업고정자산회전율',
# ...

# %%
list = df.columns[6:]
dfff = df.groupby('label_shifted')[list].mean().T

# %%
dfff['1/0'] = dfff[1] / dfff[0] 
dfff
# Out:
# label_shifted            0          1       1/0
# 타인자본비율(%)        49.381695  48.798685  0.988194
# 자기자본비율(%)        51.615502  51.239876  0.992723
# 차입금의존도(%)        29.005388  26.607308  0.917323
# 현금및현금성자산구성비율(%)  10.942861   9.598333  0.877132
# 유형자산구성비율(%)      28.104531  31.902919  1.135152
# ...                    ...        ...       ...
# 순운전자본대 총자본비율      0.616797   2.091965  3.391661
# 인건비율             39.716890   9.633195  0.242547
# 매출채권회전율          15.361188   7.601536  0.494853
# 총차입부채회전율증가율(%)   59.087923  23.283661  0.394051
# 재고자산회전율증가율(%)    24.405183   7.831990  0.320915
#
# [90 rows x 3 columns]

# %%
dfff = dfff.sort_values(by='1/0')

# %%
dfff.reset_index(inplace=True)
dfff.columns
# Out:
# Index(['index', 0, 1], dtype='object', name='label_shifted')

# %%
pd.set_option('display.max_row', None)
pd.set_option('display.expand_frame_repr', False)

# %%
label_0 = df[df['label_shifted'] == 0]
label_1 = df[df['label_shifted'] == 1]

# %%
label_0_des = label_0.describe()
label_1_des = label_1.describe()

# %%
q = pd.DataFrame()
q = label_0_des.loc[['mean']].transpose()
w = label_1_des.loc[['mean']].transpose()
q.columns = {'feature','0_mean'}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 4
#       2 q = label_0_des.loc[['mean']].transpose()
#       3 w = label_1_des.loc[['mean']].transpose()
# ----> 4 q.columns = {'feature','0_mean'}
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:6307, in NDFrame.__setattr__(self, name, value)
#    6305 try:
#    6306     object.__getattribute__(self, name)
# -> 6307     return object.__setattr__(self, name, value)
#    6308 except AttributeError:
#    6309     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     808 """
#     809 This is called from the cython code when we set the `index` attribute
#     810 directly, e.g. `series.index = [1, 2, 3]`.
#     811 """
# ...

# %%
label_1.describe()
# Out:
#                회계년  label_shifted         결산월   타인자본비율(%)   자기자본비율(%)   차입금의존도(%)  현금및현금성자산구성비율(%)  유형자산구성비율(%)  무형자산구성비율(%)       부채비율(%)      차입금비율(%)  현금흐름/총자산(%)  현금흐름/총자본(%)  현금흐름/총부채(%)   현금흐름/영업수익(%)  자기자본현금흐름률(%)  매출액증가율(전년동기)(%)  총자산증가율(전년동기)(%)  유형자산증가율(전년동기)(%)  무형자산증가율(전년동기)(%)  총부채증가율(전년동기)(%)  자본금증가율(전년동기)(%)   매출총이익률(%)    영업이익률(%)  *조정영업이익률(%)  EBITDA마진율(%)  세전계속사업이익률(%)    당기순이익률(%)  지배주주순이익률(%)    총포괄이익률(%)  지배주주총포괄이익률(%)   *매출원가율(%)    *판관비율(%)  *영업수익/영업비용(%)  ROA(영업이익)(%)  ROA(세전계속사업이익)(%)  ROA(당기순이익)(%)  ROA(총포괄이익)(%)  자본금영업이익률(%)  자본금세전계속사업이익률(%)  자본금지배주주순이익률(%)   총자산회전율(회)   총부채회전율(회)   총자본회전율(회)    자본금회전율(회)         유보율(%)  유보액/총자산(%)    ROE(영업이익)  ROE(세전계속사업이익)   ROE(당기순이익)  ROE(지배주주순이익)     투하자본회전율   영업투하자본회전율     순운전자본회전율   영업고정자산회전율  차입부채조달금리(평균)(%)  차입부채조달금리(기말)(%)  차입부채/영업수익(%)  차입부채/영업이익(배)  차입부채/EBITDA(배)  현금흐름/총차입부채(%)  판매비와관리비(천원)증가율(전년동기)(%)  영업이익(천원)증가율(전년동기)(%)  *조정영업이익(천원)증가율(전년동기)(%)  세전계속사업이익(천원)증가율(전년동기)(%)  계속사업이익(천원)증가율(전년동기)(%)  중단사업이익(천원)증
# ...

# %%
import pandas as pd
df = pd.read_csv('전처리전.csv')
df.columns = ['index','mean_0','mean_1']
df
# Out:
#                            index       mean_0       mean_1
# 0                      타인자본비율(%)    47.224254    44.140221
# 1                      자기자본비율(%)    55.620506    56.256514
# 2                      차입금의존도(%)    28.086989    23.979840
# 3                현금및현금성자산구성비율(%)     9.735930     8.467740
# 4                    유형자산구성비율(%)    24.463954    28.136818
# 5                    무형자산구성비율(%)     3.361606     3.171781
# 6                        부채비율(%)   182.017451   155.028875
# 7                       차입금비율(%)   110.871882    81.780371
# 8                     총자산/총자본(%)   282.017451   255.028875
# 9                차입부채조달금리(평균)(%)    21.076237     6.191549
# 10               차입부채조달금리(기말)(%)    22.316356    22.785992
# 11                  차입부채/영업수익(%)   172.711943    84.077685
# 12                  차입부채/영업이익(배)    54.572030    76.672366
# 13                차입부채/EBITDA(배)    35.204534    32.485484
# 14                   현금흐름/총자산(%)   -10.522975    -3.651560
# ...

# %%
dfff.reset_index(inplace=True)
dfff
# Out:
# label_shifted                         index              0              1       1/0
# 0                   지배주주순이익(천원)증가율(전년동기)(%)     676.167896    -485.380669 -0.717840
# 1              투자활동으로인한현금흐름(천원)증가율(전년동기)(%)   -1105.272301     159.449535 -0.144263
# 2              재무활동으로인한현금흐름(천원)증가율(전년동기)(%)  121160.792972  -12641.536765 -0.104337
# 3                              차입부채/영업이익(배)     -20.133137       1.612570 -0.080095
# 4                            차입부채/EBITDA(배)     -20.133137       1.612570 -0.080095
# 5                    EBITDA(천원)증가율(전년동기)(%)     123.654325      -4.100455 -0.033161
# 6                              EBITDA마진율(%)    -145.021866       2.117816 -0.014603
# 7                     매출총이익(천원)증가율(전년동기)(%)    5247.617503       5.741124  0.001094
# 8                               자본금영업이익률(%)   -1941.351119     -51.225269  0.026386
# 9                            자본금지배주주순이익률(%)   -2073.938707     -69.606077  0.033562
# ...

# %%
z = pd.merge(df, dfff, on='index', how='left')
z['0 / mean_0'] = z[0] / z['mean_0'] 
z['1 / mean_1'] = z[1] / z['mean_1']
z.sort_values(by='0 / mean_0')
z.reset_index(drop=True, inplace=True)
z.to_csv('csv/describe/전처리비교(평균_).csv', encoding='utf-8-sig')

# %% [markdown]
# ## Winsorizing

# %% [markdown]
# pd.r
